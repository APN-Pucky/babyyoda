# %%
import mplhep as hep
import babyyoda
import matplotlib.pyplot as plt

# %%
h = babyyoda.read("../../../tests/test_histo2d_v2.yoda")
h
# Out:
# {'/ALICE_2020_I1797621/GGPdfXQ': GROGU_HISTO2D_V2(d_annotations={'Path': '/ALICE_2020_I1797621/GGPdfXQ', 'ScaledBy': '1.00000000000000002e-02', 'Title': '~', 'Type': 'Histo2D'}, d_key='/ALICE_2020_I1797621/GGPdfXQ', d_bins=[GROGU_HISTO2D_V2.Bin(d_xmin=1e-06, d_xmax=1.318257e-06, d_ymin=0.0, d_ymax=0.6, d_sumw=0.0, d_sumw2=0.0, d_sumwx=0.0, d_sumwx2=0.0, d_sumwy=0.0, d_sumwy2=0.0, d_sumwxy=0.0, d_numentries=0.0), GROGU_HISTO2D_V2.Bin(d_xmin=1e-06, d_xmax=1.318257e-06, d_ymin=0.6, d_ymax=1.2, d_sumw=0.0, d_sumw2=0.0, d_sumwx=0.0, d_sumwx2=0.0, d_sumwy=0.0, d_sumwy2=0.0, d_sumwxy=0.0, d_numentries=0.0), GROGU_HISTO2D_V2.Bin(d_xmin=1e-06, d_xmax=1.318257e-06, d_ymin=1.2, d_ymax=1.8, d_sumw=0.0, d_sumw2=0.0, d_sumwx=0.0, d_sumwx2=0.0, d_sumwy=0.0, d_sumwy2=0.0, d_sumwxy=0.0, d_numentries=0.0), GROGU_HISTO2D_V2.Bin(d_xmin=1e-06, d_xmax=1.318257e-06, d_ymin=1.8, d_ymax=2.4, d_sumw=0.0, d_sumw2=0.0, d_sumwx=0.0, d_sumwx2=0.0, d_sumwy=0.0, d_sumwy2=0.0, d_sumwxy=0.0, d_numentries=0.0), GROGU_
# ...

# %%
hep.hist2dplot(
            h['/ALICE_2020_I1797621/GGPdfXQ'],
            binwnorm=1.0
        )
plt.xscale('log')
