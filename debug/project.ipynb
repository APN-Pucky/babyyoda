# %%
import babyyoda.grogu as yoda
from babyyoda import project, rebin

# %%
hists = yoda.read("../tests/test_histo1d_v3.yoda")

# %%
h = hists["/"][:: rebin(2)]
h

# %%
h[2:5]

# %%
h[2:5:project]
# Out:
# PROJECT

# %%
from matplotlib import pyplot as plt

plt.figure()
a = [1, 2, 5, 6, 9, 11, 15, 17, 18]
plt.hlines(1, 1, 20)  # Draw a horizontal line
plt.eventplot(a, orientation="horizontal", colors="b")
plt.ax.get_xaxis().set_visible(False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 8
#       6 plt.hlines(1,1,20)  # Draw a horizontal line
#       7 plt.eventplot(a, orientation='horizontal', colors='b')
# ----> 8 plt.ax.get_xaxis().set_visible(False)
#       9 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ax'

# %%
import matplotlib.pyplot as plt

# Sample data
y = [2, 4, 6, 8]
yerr = [0.5, 0.4, 0.3, 0.2]

# Plotting
plt.errorbar(x=[0] * len(y), y=y, yerr=yerr, fmt=" ", capsize=5)

# Remove x-axis labels and ticks
plt.gca().get_xaxis().set_visible(False)

# Show the plot
plt.show()
