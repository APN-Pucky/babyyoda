# %%
import babyyoda.grogu as yoda
from babyyoda import project, rebin

# %%
hists = yoda.read("../tests/test_histo1d_v3.yoda")

# %%
h = hists["/"][:: rebin(2)]
h

# %%
h[2:5]

# %%
h[2:5:project]

# %%
hists = yoda.read("../tests/test_histo2d_v3.yoda")

# %%
h = next(iter(hists.values()))

# %%
h

# %%
h[0, :]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 h[0,:]
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/histo2d.py:292, in UHIHisto2D.__getitem__(self, slices)
#     290     if ystop is not None:
#     291         ystop += 1
# --> 292     sc.rebinYTo(self.yEdges()[ystart:ystop])
#     294 if isinstance(xstep, rebin):
#     295     # weird yoda default
#     296     if xstart is None:
#
# AttributeError: 'GROGU_HISTO2D_V3' object has no attribute 'rebinYTo'

# %%
h[0, 0].sumWY()

# %%
h.projectX()

# %%
h.projectY()

# %%
h[0:5:project, 0:5:project]

# %%
h[0:5:project, 0:5]

# %%
h[0:5, 0:5:project]
