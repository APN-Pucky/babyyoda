# %%
from babyyoda import project, rebin, yoda

# %%
hists = yoda.read("../tests/test_histo1d_v3.yoda")

# %%
h = hists["/"][:: rebin(2)]
h

# %%
h[2:5]

# %%
h[2:5:project]

# %%
hists = yoda.read("../tests/test_histo2d_v3.yoda")

# %%
h = next(iter(hists.values()))

# %%
h
# Out:
# Warning: <class 'babyyoda.yoda.histo2d.Histo2D'> is not allowed to get flow bins, flow bin option set to None

# %%
h[0, :]

# %%
h[0, 0].sumWY()
# Out:
# 0.0

# %%
h.projectX()

# %%
h.projectY()

# %%
h[0:5:project, 0:5:project]

# %%
h[0:5:project, 0:5]

# %%
h[0:5, 0:5:project]
