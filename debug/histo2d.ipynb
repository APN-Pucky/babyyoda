# new x axis [9.120108e-06, 1.202264e-05, 1.584893e-05, 2.089296e-05, 2.754229e-05, 3.630781e-05, 4.786301e-05, 6.309573e-05, 8.317638e-05, 0.0001096478, 0.000144544, 0.0001905461, 0.0002511886, 0.0003311311, 0.0004365158, 0.0005754399, 0.0007585776, 0.001, 0.001318257, 0.001737801, 0.002290868, 0.003019952, 0.003981072, 0.005248075, 0.00691831, 0.009120108]
# Warning: <class 'babyyoda.Histo2D.Histo2D'> is not allowed to get flow bins, flow bin option set to None

# %%
print(1e-2)
# Out:
# 0.01

# %%
hists = grogu.read_grogu("../tests/test_histo2d_v2.yoda")
h = hists["/ALICE_2020_I1797621/GGPdfXQ"]
h
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/lib/python3.12/site-packages/IPython/core/formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:233, in Histo2D._ipython_display_(self)
#     231 def _ipython_display_(self):
#     232     try:
# --> 233         self.plot()
#     234     except ImportError:
#     235         pass
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:228, in Histo2D.plot(self, *args, **kwargs)
#     223     return np.array([b.sumW() / b.dVol() for b in self.bins()]).reshape(
#     224         (len(self.axes[0]), len(self.axes[1]))
#     225     )
#     227 self.values = temp_values
# --> 228 hep.hist2dplot(self, *args, **kwargs)
#     229 self.values = saved_values
#
# File ~/.local/lib/python3.12/site-packages/mplhep/plot.py:748, in hist2dplot(H, xbins, ybins, labels, cbar, cbarsize, cbarpad, cbarpos, cbarextend, cmin, cmax, ax, flow, **kwargs)
#     745     if not isinstance(ax, plt.Axes):
#     746         raise ValueError("ax must be a matplotlib Axes object")
# --> 748 h = hist_object_handler(H, xbins, ybins)
#     750 # TODO: use Histogram everywhere
#     752 H = np.copy(h.values())
#
# File ~/.local/lib/python3.12/site-packages/mplhep/utils.py:59, in hist_object_handler(hist, *bins)
#      56 else:
#      57     hist_obj = ensure_plottable_histogram((hist, *bins))
# ---> 59 if len(hist_obj.axes) not in {1, 2}:
#      60     raise ValueError("Must have only 1 or 2 axes")
#      62 return hist_obj
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:21, in Histo2D.__getattr__(self, name)
#      18 def __getattr__(self, name):
#      19     # yoda-1 has overflow but yoda-2 does not so we patch it in here
#      20     if name in self.__dict__ or hasattr(type(self), name):
# ---> 21         return object.__getattribute__(self, name)
#      22     elif hasattr(self.target, name):
#      23         return getattr(self.target, name)
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:97, in Histo2D.axes(self)
#      94 @property
#      95 def axes(self):
#      96     return [
# ---> 97         list(zip(self.xMins(), self.xMaxs())),
#      98         list(zip(self.yMins(), self.yMaxs())),
#      99     ]
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:69, in Histo2D.xMins(self)
#      68 def xMins(self):
# ---> 69     return self.xEdges()[:-1]
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:24, in Histo2D.__getattr__(self, name)
#      22 elif hasattr(self.target, name):
#      23     return getattr(self.target, name)
# ---> 24 raise AttributeError(
#      25     f"'{type(self).__name__}' object and target have no attribute '{name}'"
#      26 )
#
# AttributeError: 'Histo2D' object and target have no attribute 'xEdges'

# %%
hists["/ALICE_2020_I1797621/GGPdfXQ"].plot()
# plot.yscale("log")
plot.xscale("log")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 hists["/ALICE_2020_I1797621/GGPdfXQ"].plot()
#       2 # plot.yscale("log")
#       3 plot.xscale("log")
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:228, in Histo2D.plot(self, *args, **kwargs)
#     223     return np.array([b.sumW() / b.dVol() for b in self.bins()]).reshape(
#     224         (len(self.axes[0]), len(self.axes[1]))
#     225     )
#     227 self.values = temp_values
# --> 228 hep.hist2dplot(self, *args, **kwargs)
#     229 self.values = saved_values
#
# File ~/.local/lib/python3.12/site-packages/mplhep/plot.py:748, in hist2dplot(H, xbins, ybins, labels, cbar, cbarsize, cbarpad, cbarpos, cbarextend, cmin, cmax, ax, flow, **kwargs)
#     745     if not isinstance(ax, plt.Axes):
#     746         raise ValueError("ax must be a matplotlib Axes object")
# --> 748 h = hist_object_handler(H, xbins, ybins)
#     750 # TODO: use Histogram everywhere
#     752 H = np.copy(h.values())
#
# File ~/.local/lib/python3.12/site-packages/mplhep/utils.py:59, in hist_object_handler(hist, *bins)
#      56 else:
#      57     hist_obj = ensure_plottable_histogram((hist, *bins))
# ---> 59 if len(hist_obj.axes) not in {1, 2}:
#      60     raise ValueError("Must have only 1 or 2 axes")
#      62 return hist_obj
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:21, in Histo2D.__getattr__(self, name)
#      18 def __getattr__(self, name):
#      19     # yoda-1 has overflow but yoda-2 does not so we patch it in here
#      20     if name in self.__dict__ or hasattr(type(self), name):
# ---> 21         return object.__getattribute__(self, name)
#      22     elif hasattr(self.target, name):
#      23         return getattr(self.target, name)
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:97, in Histo2D.axes(self)
#      94 @property
#      95 def axes(self):
#      96     return [
# ---> 97         list(zip(self.xMins(), self.xMaxs())),
#      98         list(zip(self.yMins(), self.yMaxs())),
#      99     ]
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:69, in Histo2D.xMins(self)
#      68 def xMins(self):
# ---> 69     return self.xEdges()[:-1]
#
# File ~/.local/lib/python3.12/site-packages/babyyoda/Histo2D.py:24, in Histo2D.__getattr__(self, name)
#      22 elif hasattr(self.target, name):
#      23     return getattr(self.target, name)
# ---> 24 raise AttributeError(
#      25     f"'{type(self).__name__}' object and target have no attribute '{name}'"
#      26 )
#
# AttributeError: 'Histo2D' object and target have no attribute 'xEdges'

# %%
hists = grogu.read_grogu("../tests/test_histo2d_v2.yoda")
h = hists["/ALICE_2020_I1797621/GGPdfXQ"]
h.bins()[0]
print(len(h.bins()))
for b in h.bins():
    print(b.xMin(), b.xMax(), b.yMin(), b.yMax())

# %%
hists = grogu.read_yoda("../tests/test_histo2d_v2.yoda")
h = hists["/ALICE_2020_I1797621/GGPdfXQ"]
h

# %%
hists = grogu.read_yoda("../tests/test_histo2d_v2.yoda")
hists["/ALICE_2020_I1797621/GGPdfXQ"].plot()
# plot.yscale("log")
plot.xscale("log")

# %%
hists = grogu.read_yoda("../tests/test_histo2d_v2.yoda")
h = hists["/ALICE_2020_I1797621/GGPdfXQ"]
print(len(h.bins()))
for b in h.bins():
    print(b.xMin(), b.xMax(), b.yMin(), b.yMax())

# %%
h

# %%
h[:, :]
